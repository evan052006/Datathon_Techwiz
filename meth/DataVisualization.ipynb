# %% [markdown]
# # Researching Given Data

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
DonovanPathDirectory = "/mnt/d/Hackathon/DatathonRistek/Datathon_Techwiz/CSVData/"
coryKenshinRandomVideos = pd.read_csv(os.path.join(DonovanPathDirectory, "CoryKenshinRandomVideosPlaylist.csv"))
musicVideos = pd.read_csv(os.path.join(DonovanPathDirectory, "MusicVideosPlaylist.csv"))
vinesComedyVideos = pd.read_csv(os.path.join(DonovanPathDirectory, "VinesComedyVideosPlaylist.csv"))

coryKenshinRandomVideos.head()
# Out:
#    Unnamed: 0  comment_count  view_count  like_count  \
# 0           1         295000    18270143      903187
# 1           2         100000     3969031      449915
# 2           3          29000     4555735      373542
# 3           4         130000    10211898      876158
# 4           5          94000    10396076     1181262
#
#                                                title  \
# 0  Reacting to the Five Nights at Freddy's Movie ...
# 1                                                 30
# 2                       I Can't Hide This Any Longer
# 3                       Deleting My YouTube Channel.
# 4                     YouTube: Racism and Favoritism
#
#                                          description       channel  \
# 0  Trailer: https://www.youtube.com/watch?v=0VH9W...  CoryxKenshin
# 1  this video has no purpose other than for me to...  CoryxKenshin
# 2  https://coryxkenshin.com GOGOGOGO BEFORE IT SE...  CoryxKenshin
# ...

# %%
musicVideos.head()
# Out:
#    video_index  comment_count  view_count  like_count  \
# 0            1        4300000  8751645121    54956225
# 1            2        2300000  6710469143    45186342
# 2            3        1200000  6499341796    34496973
# 3            4         435000  4252160992    16692077
# 4            5         524000  4191809528    18563457
#
#                                                title  \
# 0            Luis Fonsi - Despacito ft. Daddy Yankee
# 1  Wiz Khalifa - See You Again ft. Charlie Puth [...
# 2   Ed Sheeran - Shape of You (Official Music Video)
# 3            Maroon 5 - Sugar (Official Music Video)
# 4                       OneRepublic - Counting Stars
#
#                                          description      channel  \
# 0  “Despacito” disponible ya en todas las platafo...   Luis Fonsi
# 1  Download the new Furious 7 Soundtrack Deluxe V...  Wiz Khalifa
# 2  The official music video for Ed Sheeran - Shap...   Ed Sheeran
# ...

# %%
vinesComedyVideos.head()
# Out:
#    Unnamed: 0  comment_count  view_count  like_count  \
# 0           1             12       19400         363
# 1           2             94      377724        5263
# 2           3             80      242371        4564
# 3           4             37      163481        2738
# 4           5             77      212974        3639
#
#                                             title  \
# 0   Funny Vines July 2024 (Part 1) TBT Clean Vine
# 1   Funny Vines July 2022 (Part 2) TBT Clean Vine
# 2  Funny Vines April 2022 (Part 1) TBT Clean Vine
# 3  Funny Vines March 2022 (Part 1) TBT Clean Vine
# 4  Funny Vines March 2022 (Part 2) TBT Clean Vine
#
#                                          description     channel  \
# 0  New TBT Vine Videos with the Best Clean Vines ...  CooL Vines
# 1  New TBT Vine with the Best Clean Vines of July...  CooL Vines
# 2  New TBT Vine with the Best Clean Vines of Apri...  CooL Vines
# 3  New TBT Vine with the Best Clean Vines of Marc...  CooL Vines
# ...

# %%
xAxis = np.array(musicVideos['view_count'])
yAxis = np.array(musicVideos['like_count'])

plt.scatter(xAxis, yAxis, color='blue', label='Music Videos')
plt.show()

# %%
xAxis = np.array(coryKenshinRandomVideos['view_count'])
yAxis = np.array(coryKenshinRandomVideos['like_count'])

plt.scatter(xAxis, yAxis, color='blue', label='Music Videos')
plt.show()

# %%
xAxis = np.array(vinesComedyVideos['view_count'])
yAxis = np.array(vinesComedyVideos['like_count'])

plt.scatter(xAxis, yAxis, color='blue', label='Music Videos')
plt.show()
